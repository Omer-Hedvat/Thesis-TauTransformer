# %%
import pandas as pd
from scipy import stats

# %%
data = pd.read_csv("results/all_datasets_results.csv")

# %%
data = pd.read_csv('results/all_datasets_results.csv')
i = 0
for dataset_name in ['digits', 'ml_multiclass_classification_data', 'otto', 'crop', 'glass', 'isolet']:
    data1 = data[data['dataset'] == dataset_name]
    A_type = ['random_features', 'fisher', 'relief', 'Chi_square']
    B_type = ['hellinger_rank', 'hellinger_kmeans',
       'hellinger_kmediods', 'hellinger_distance_from_0', 'jm_rank',
       'jm_kmeans', 'jm_kmediods', 'jm_distance_from_0', 'wasserstein_rank',
       'wasserstein_kmeans', 'wasserstein_kmediods',
       'wasserstein_distance_from_0']
    df = pd.DataFrame(data={'dataset': [dataset_name]})
    for a in A_type:
        for b in B_type:
            # t test is A>B
            df[a + ' ' + b] = stats.ttest_rel(data1[a], data1[b], alternative='less')[1]
    if i>0:
        old_df = pd.read_csv('t_test_results.csv')
        df = pd.concat([df, old_df], ignore_index=True)
        
    df.to_csv('t_test_results.csv')
    i += 1

# %%
df
# Out:
#                              dataset  random_features hellinger_rank  \
# 0                             isolet                        1.000000
# 1                              glass                        0.000540
# 2                               crop                        0.999999
# 3                               otto                        0.951639
# 4  ml_multiclass_classification_data                        1.000000
# 5                             digits                        0.999985
#
#    random_features hellinger_kmeans  random_features hellinger_kmediods  \
# 0                      1.000000e+00                        1.807746e-07
# 1                      9.999824e-01                        7.793881e-01
# 2                      1.000000e+00                        5.009484e-05
# 3                      3.967758e-07                        8.820517e-01
# 4                      9.922644e-06                        9.407251e-01
# 5                      1.000000e+00                        3.233365e-08
#
#    random_features hellinger_distance_from_0  random_features jm_rank  \
# 0                                   0.999999                 0.999999
# 1                                   0.973961                 0.998389
# 2                                   1.000000                 0.999975
# 3                                   0.324074                 0.241139
# 4                                   1.000000                 1.000000
# 5                                   0.999733                 0.999998
#
#    random_features jm_kmeans  random_features jm_kmediods  \
# 0               6.492762e-01                     1.000000
# 1               9.999943e-01                     0.846316
# 2               6.499480e-10                     0.608389
# 3               9.979747e-01                     0.024129
# 4               2.365340e-05                     0.959151
# 5               3.438498e-14                     1.000000
#
#    random_features jm_distance_from_0  random_features wasserstein_rank  ...  \
# 0                        1.000000e+00                          1.000000  ...
# 1                        6.706964e-01                          0.995245  ...
# 2                        1.000000e+00                          0.999776  ...
# 3                        9.999101e-01                          1.000000  ...
# 4                        1.000000e+00                          1.000000  ...
# 5                        6.405719e-07                          0.992249  ...
#
#    Chi_square jm_distance_from_0  Chi_square wasserstein_rank  \
# 0                   1.301355e-31                 9.999931e-01
# 1                   3.577099e-01                 9.851807e-01
# 2                   1.000000e+00                 9.999883e-01
# 3                   1.000000e+00                 1.000000e+00
# 4                   2.378538e-24                 1.645226e-21
# 5                   8.523463e-30                 8.715698e-01
#
#    Chi_square wasserstein_kmeans  Chi_square wasserstein_kmediods  \
# 0                   3.873467e-33                     3.223466e-24
# 1                   8.237568e-07                     9.805915e-01
# 2                   2.976462e-01                     1.000000e+00
# 3                   1.000000e+00                     1.000000e+00
# 4                   8.350824e-33                     4.364989e-25
# 5                   3.078750e-27                     1.325138e-27
#
#    Chi_square wasserstein_distance_from_0  Unnamed: 0  Unnamed: 0.1  \
# 0                            7.295854e-50         NaN           NaN
# 1                            3.196085e-03         0.0           NaN
# 2                            1.000000e+00         1.0           0.0
# 3                            1.000000e+00         2.0           1.0
# 4                            3.130861e-23         3.0           2.0
# 5                            9.988768e-01         4.0           3.0
#
#    Unnamed: 0.1.1  Unnamed: 0.1.1.1  Unnamed: 0.1.1.1.1
# 0             NaN               NaN                 NaN
# 1             NaN               NaN                 NaN
# 2             NaN               NaN                 NaN
# 3             0.0               NaN                 NaN
# 4             1.0               0.0                 NaN
# 5             2.0               1.0                 0.0
#
# [6 rows x 54 columns]

# %%
B_type
# Out:
# Index(['relief', 'Chi_square', 'hellinger_rank', 'hellinger_kmeans',
#        'hellinger_kmediods', 'hellinger_distance_from_0', 'jm_rank',
#        'jm_kmeans', 'jm_kmediods', 'jm_distance_from_0', 'wasserstein_rank',
#        'wasserstein_kmeans', 'wasserstein_kmediods',
#        'wasserstein_distance_from_0'],
#       dtype='object')

# %%
A_type = ['random_features','fisher','relief','Chi_square']
B_type = data.iloc[:,8:].columns

# %%
df = pd.DataFrame(data={'dataset': [dataset]})

# %%
for a in A_type:
    for b in B_type:
        df[a+' '+b] = stats.ttest_ind(data[a],data[b], alternative ='less')[1]

# %%
old_df =  pd.read_csv('t_test_results.csv')

# %%
old_df
# Out:
#    Unnamed: 0   dataset  random_features hellinger_rank  \
# 0           0  spambase                        0.472913
#
#    random_features hellinger_kmeans  random_features hellinger_kmediods  \
# 0                          0.389426                            0.238774
#
#    random_features hellinger_distance_from_0  random_features jm_rank  \
# 0                                   0.471889                 0.509563
#
#    random_features jm_kmeans  random_features jm_kmediods  \
# 0                   0.340027                     0.392522
#
#    random_features jm_distance_from_0  ...  Chi_square hellinger_kmediods  \
# 0                            0.697496  ...                       0.943255
#
#    Chi_square hellinger_distance_from_0  Chi_square jm_rank  \
# 0                              0.973176            0.961456
#
#    Chi_square jm_kmeans  Chi_square jm_kmediods  \
# 0              0.944928                0.943038
#
#    Chi_square jm_distance_from_0  Chi_square wasserstein_rank  \
# 0                       0.960838                     0.981001
#
#    Chi_square wasserstein_kmeans  Chi_square wasserstein_kmediods  \
# 0                       0.895304                         0.953514
#
#    Chi_square wasserstein_distance_from_0
# 0                                0.937717
#
# [1 rows x 50 columns]

# %%
df
# Out:
#   dataset  random_features hellinger_rank  random_features hellinger_kmeans  \
# 0   glass                        0.200032                          0.434975
#
#    random_features hellinger_kmediods  \
# 0                            0.320436
#
#    random_features hellinger_distance_from_0  random_features jm_rank  \
# 0                                    0.29731                  0.22223
#
#    random_features jm_kmeans  random_features jm_kmediods  \
# 0                   0.432627                     0.246554
#
#    random_features jm_distance_from_0  random_features wasserstein_rank  ...  \
# 0                            0.222885                          0.195542  ...
#
#    Chi_square hellinger_kmediods  Chi_square hellinger_distance_from_0  \
# 0                       0.518014                              0.469882
#
#    Chi_square jm_rank  Chi_square jm_kmeans  Chi_square jm_kmediods  \
# 0            0.378173              0.657133                0.412141
#
#    Chi_square jm_distance_from_0  Chi_square wasserstein_rank  \
# 0                       0.373243                     0.338573
#
#    Chi_square wasserstein_kmeans  Chi_square wasserstein_kmediods  \
# 0                       0.271943                         0.651185
#
#    Chi_square wasserstein_distance_from_0
# 0                                0.194213
#
# [1 rows x 49 columns]

# %%
df = df.append(old_df)

# %%
df
# Out:
#     dataset  random_features hellinger_rank  random_features hellinger_kmeans  \
# 0     glass                        0.200032                          0.434975
# 0  spambase                        0.472913                          0.389426
#
#    random_features hellinger_kmediods  \
# 0                            0.320436
# 0                            0.238774
#
#    random_features hellinger_distance_from_0  random_features jm_rank  \
# 0                                   0.297310                 0.222230
# 0                                   0.471889                 0.509563
#
#    random_features jm_kmeans  random_features jm_kmediods  \
# 0                   0.432627                     0.246554
# 0                   0.340027                     0.392522
#
#    random_features jm_distance_from_0  random_features wasserstein_rank  ...  \
# 0                            0.222885                          0.195542  ...
# 0                            0.697496                          0.723770  ...
#
#    Chi_square hellinger_distance_from_0  Chi_square jm_rank  \
# 0                              0.469882            0.378173
# 0                              0.973176            0.961456
#
#    Chi_square jm_kmeans  Chi_square jm_kmediods  \
# 0              0.657133                0.412141
# 0              0.944928                0.943038
#
#    Chi_square jm_distance_from_0  Chi_square wasserstein_rank  \
# 0                       0.373243                     0.338573
# 0                       0.960838                     0.981001
#
#    Chi_square wasserstein_kmeans  Chi_square wasserstein_kmediods  \
# 0                       0.271943                         0.651185
# 0                       0.895304                         0.953514
#
#    Chi_square wasserstein_distance_from_0  Unnamed: 0
# 0                                0.194213         NaN
# 0                                0.937717         0.0
#
# [2 rows x 50 columns]
